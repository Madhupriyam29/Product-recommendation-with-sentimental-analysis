# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("C:/Users/Madhu/Downloads/lap_details.csv")

# Display the DataFrame
print(df)
# Out:
#                                           product_name  \
# 0    Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# 1    Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# 2    Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# 3    Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# 4    Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# ..                                                 ...
# 151  HP 15s Intel Core i3 12th Gen 1215U - (8 GB/51...
# 152  HP 15s Intel Core i3 12th Gen 1215U - (8 GB/51...
# 153  HP 15s Intel Core i3 12th Gen 1215U - (8 GB/51...
# 154  HP 15s Intel Core i3 12th Gen 1215U - (8 GB/51...
# 155  HP 15s Intel Core i3 12th Gen 1215U - (8 GB/51...
#
#                                     performance_review  \
# 0    ["...Literally M2's have crucial or beast perf...
# 1    ['...Nice product by apple. Good performance a...
# 2    ["...But there are some drawbacks like price i...
# 3    ['...The complete laptop for daily use. Speed ...
# ...

# %%
df
# Out:
#                                           product_name  \
# 0    Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# 1    Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# 2    Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# 3    Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# 4    Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# ..                                                 ...
# 151  HP 15s Intel Core i3 12th Gen 1215U - (8 GB/51...
# 152  HP 15s Intel Core i3 12th Gen 1215U - (8 GB/51...
# 153  HP 15s Intel Core i3 12th Gen 1215U - (8 GB/51...
# 154  HP 15s Intel Core i3 12th Gen 1215U - (8 GB/51...
# 155  HP 15s Intel Core i3 12th Gen 1215U - (8 GB/51...
#
#                                     performance_review  \
# 0    ["...Literally M2's have crucial or beast perf...
# 1    ['...Nice product by apple. Good performance a...
# 2    ["...But there are some drawbacks like price i...
# 3    ['...The complete laptop for daily use. Speed ...
# ...

# %%
df.isnull().sum()
# Out:
# product_name            0
# performance_review     24
# battery_review         33
# design_review         122
# display_review         99
# display_quality       153
# dtype: int64

# %%
df.drop(columns=['battery_review','design_review','display_review','display_quality'], inplace=True)

# %%
df
# Out:
#                                           product_name  \
# 0    Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# 1    Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# 2    Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# 3    Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# 4    Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# ..                                                 ...
# 151  HP 15s Intel Core i3 12th Gen 1215U - (8 GB/51...
# 152  HP 15s Intel Core i3 12th Gen 1215U - (8 GB/51...
# 153  HP 15s Intel Core i3 12th Gen 1215U - (8 GB/51...
# 154  HP 15s Intel Core i3 12th Gen 1215U - (8 GB/51...
# 155  HP 15s Intel Core i3 12th Gen 1215U - (8 GB/51...
#
#                                     performance_review
# 0    ["...Literally M2's have crucial or beast perf...
# 1    ['...Nice product by apple. Good performance a...
# 2    ["...But there are some drawbacks like price i...
# 3    ['...The complete laptop for daily use. Speed ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_name        156 non-null    object
#  1   performance_review  132 non-null    object
# dtypes: object(2)
# memory usage: 2.6+ KB

# %%
# Convert DataFrame to CSV
df.to_csv('C:/Users/Madhu/Downloads/lapcleaned_detail.csv', index=False)

# %%
import pandas as pd
from textblob import TextBlob

# Load the data
df = pd.read_csv('C:/Users/Madhu/Downloads/lapcleaned_detail.csv')

# Function to get sentiment
def get_sentiment(performance_review):
    if isinstance(performance_review, str):  # Check if the review is a string
        analysis = TextBlob(performance_review)
        if analysis.sentiment.polarity > 0:
            return 'Positive'
        elif analysis.sentiment.polarity < 0:
            return 'Negative'
        else:
            return 'Neutral'
    else:
        return 'Neutral'  # Handle non-string entries

# Apply the function to the review column
df['Sentiment'] = df['performance_review'].apply(get_sentiment)

# Save the updated DataFrame to a new CSV file
df.to_csv('C:/Users/Madhu/Downloads/lapsentiment_detail.csv', index=False)

# Display the first few rows to verify
print(df[['performance_review', 'Sentiment']].head())
# Out:
#                                   performance_review Sentiment
# 0  ["...Literally M2's have crucial or beast perf...   Neutral
# 1  ['...Nice product by apple. Good performance a...  Positive
# 2  ["...But there are some drawbacks like price i...  Positive
# 3  ['...The complete laptop for daily use. Speed ...  Positive
# 4  ['...Great laptop. Very good performance, batt...  Positive

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('C:/Users/Madhu/Downloads/lapsentiment_detail.csv')

# Define the sentiment score mapping
sentiment_scores = {
    'Positive': 1,
    'Neutral': 0,
    'Negative': -1
}

# Map the Sentiment column to sentiment scores
df['Sentiment_Score'] = df['Sentiment'].map(sentiment_scores)

# Display the first few rows to verify
print(df.head())

# Optionally, save the updated DataFrame to a new CSV
df.to_csv('C:/Users/Madhu/Downloads/lap_reviews_with_scores.csv', index=False)
# Out:
#                                         product_name  \
# 0  Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# 1  Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# 2  Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# 3  Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# 4  Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
#
#                                   performance_review Sentiment  \
# 0  ["...Literally M2's have crucial or beast perf...   Neutral
# 1  ['...Nice product by apple. Good performance a...  Positive
# 2  ["...But there are some drawbacks like price i...  Positive
# 3  ['...The complete laptop for daily use. Speed ...  Positive
# 4  ['...Great laptop. Very good performance, batt...  Positive
#
#    Sentiment_Score
# 0                0
# 1                1
# 2                1
# 3                1
# 4                1

# %%
df
# Out:
#                                           product_name  \
# 0    Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# 1    Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# 2    Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# 3    Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# 4    Apple MacBook AIR Apple M2 - (8 GB/256 GB SSD/...
# ..                                                 ...
# 151  HP 15s Intel Core i3 12th Gen 1215U - (8 GB/51...
# 152  HP 15s Intel Core i3 12th Gen 1215U - (8 GB/51...
# 153  HP 15s Intel Core i3 12th Gen 1215U - (8 GB/51...
# 154  HP 15s Intel Core i3 12th Gen 1215U - (8 GB/51...
# 155  HP 15s Intel Core i3 12th Gen 1215U - (8 GB/51...
#
#                                     performance_review Sentiment  \
# 0    ["...Literally M2's have crucial or beast perf...   Neutral
# 1    ['...Nice product by apple. Good performance a...  Positive
# 2    ["...But there are some drawbacks like price i...  Positive
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'Rating' is a column in the DataFrame
plt.figure(figsize=(8, 6))
sns.countplot(x='performance_review', data=df, palette='viridis')
plt.title('Distribution of performance_review')
plt.xlabel('performance_review')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Madhu\AppData\Local\Temp\ipykernel_8948\699088369.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='performance_review', data=df, palette='viridis')
# c:\Users\Madhu\OneDrive\Desktop\vscode\.venv\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128076 (\N{OK HAND SIGN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Madhu\OneDrive\Desktop\vscode\.venv\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 10024 (\N{SPARKLES}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Madhu\OneDrive\Desktop\vscode\.venv\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128176 (\N{MONEY BAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# Assuming 'Sentiment_Score' is the column with mapped scores
plt.figure(figsize=(8, 6))
sns.countplot(x='Sentiment_Score', data=df, palette='coolwarm')
plt.title('Distribution of Sentiment Scores')
plt.xlabel('Sentiment Score')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Madhu\AppData\Local\Temp\ipykernel_8948\2150735539.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Sentiment_Score', data=df, palette='coolwarm')

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['product_name'], bins=5, kde=True, color='blue')
plt.title('Rating Distribution of Products')
plt.xlabel('product_name')
plt.ylabel('Frequency')
plt.show()

# %%
# Out:
# Empty DataFrame
# Columns: [product_name, performance_review, battery_review, design_review, display_review, display_quality]
# Index: []
